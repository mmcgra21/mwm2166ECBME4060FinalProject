# %%
#@title Install prerequsite
# !pip install GEOparse
# Out:
# Collecting GEOparse
#   Downloading GEOparse-2.0.3.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 8.3 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from GEOparse) (1.19.5)
# Requirement already satisfied: pandas>=0.17 in /usr/local/lib/python3.7/dist-packages (from GEOparse) (1.1.5)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from GEOparse) (2.23.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.7/dist-packages (from GEOparse) (4.62.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17->GEOparse) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17->GEOparse) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17->GEOparse) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->GEOparse) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->GEOparse) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->GEOparse) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->GEOparse) (1.24.3)
# Building wheels for collected packages: GEOparse
#   Building wheel for GEOparse (setup.py) ... done
#   Created wheel for GEOparse: filename=GEOparse-2.0.3-py3-none-any.whl size=29063 sha256=5839c02ceb857e74bf7f541d332629bff3525d15be1280a4af8dd507d3dbb76e
#   Stored in directory: /root/.cache/pip/wheels/4d/15/e8/fbf3b47444215d9728c20d7b35436b50086aa67c2ad6dcedad
# Successfully built GEOparse
# Installing collected packages: GEOparse
# Successfully installed GEOparse-2.0.3

# %%
#@title Mount Google Drive (You don't need to run this if you are running notebooks on your laptop)

from google.colab import drive

# The following command will prompt a URL for you to click and obtain the
# authorization code

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# This code is an attempt to reproduce the analysis preformed in the following paper: ["Upper airway gene expression reveals suppressed immune responses to SARS-CoV-2 compared with other respiratory viruses"](https://pubmed.ncbi.nlm.nih.gov/33203890/) by Mick, Kamm, et al. published in *Nature Communications*.

# %% [markdown]
# First we need to download the data from the NCBI Database [here](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE156063).
#
# Download the following zip files and move them into your drive: [GSE156063_swab_gene_counts.csv.gz](https://ftp.ncbi.nlm.nih.gov/geo/series/GSE156nnn/GSE156063/suppl/GSE156063_swab_gene_counts.csv.gz) (count matrix) and [GSE156063_family.soft.gz](https://ftp.ncbi.nlm.nih.gov/geo/series/GSE156nnn/GSE156063/soft/GSE156063_family.soft.gz) (metadata).

# %%
# Set up data folder
from pathlib import Path

DATA = Path("/content/drive/My Drive/Geonomics_E4060/data/project")

# %% [markdown]
# Unzip and load the metadata, we will have to use GEOParse.

# %%
# Read in the metadata and preprocess into a dataframe
import GEOparse

metadata_file = DATA / "GSE156063_family.soft.gz"

gse = GEOparse.get_GEO(filepath=str(metadata_file))
# Out:
# 20-Dec-2021 22:51:08 INFO GEOparse - Parsing /content/drive/My Drive/Geonomics_E4060/data/project/GSE156063_family.soft.gz:
# 20-Dec-2021 22:51:08 DEBUG GEOparse - DATABASE: GeoMiame
# 20-Dec-2021 22:51:08 DEBUG GEOparse - SERIES: GSE156063
# 20-Dec-2021 22:51:08 DEBUG GEOparse - PLATFORM: GPL24676
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721578
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721579
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721580
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721581
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721582
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721583
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721584
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721585
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721586
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721587
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721588
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721589
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721590
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721591
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721592
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721593
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721594
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721595
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721596
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721597
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721598
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721599
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721600
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721601
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721602
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721603
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721604
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721605
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721606
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721607
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721608
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721609
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721610
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721611
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721612
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721613
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721614
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721615
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721616
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721617
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721618
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721619
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721620
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721621
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721622
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721623
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721624
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721625
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721626
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721627
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721628
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721629
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721630
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721631
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721632
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721633
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721634
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721635
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721636
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721637
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721638
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721639
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721640
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721641
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721642
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721643
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721644
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721645
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721646
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721647
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721648
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721649
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721650
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721651
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721652
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721653
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721654
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721655
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721656
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721657
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721658
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721659
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721660
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721661
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721662
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721663
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721664
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721665
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721666
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721667
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721668
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721669
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721670
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721671
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721672
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721673
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721674
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721675
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721676
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721677
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721678
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721679
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721680
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721681
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721682
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721683
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721684
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721685
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721686
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721687
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721688
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721689
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721690
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721691
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721692
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721693
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721694
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721695
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721696
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721697
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721698
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721699
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721700
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721701
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721702
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721703
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721704
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721705
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721706
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721707
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721708
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721709
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721710
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721711
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721712
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721713
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721714
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721715
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721716
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721717
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721718
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721719
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721720
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721721
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721722
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721723
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721724
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721725
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721726
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721727
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721728
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721729
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721730
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721731
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721732
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721733
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721734
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721735
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721736
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721737
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721738
# 20-Dec-2021 22:51:09 DEBUG GEOparse - SAMPLE: GSM4721739
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721740
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721741
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721742
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721743
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721744
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721745
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721746
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721747
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721748
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721749
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721750
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721751
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721752
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721753
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721754
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721755
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721756
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721757
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721758
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721759
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721760
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721761
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721762
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721763
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721764
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721765
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721766
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721767
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721768
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721769
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721770
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721771
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721772
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721773
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721774
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721775
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721776
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721777
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721778
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721779
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721780
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721781
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721782
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721783
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721784
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721785
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721786
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721787
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721788
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721789
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721790
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721791
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721792
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721793
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721794
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721795
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721796
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721797
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721798
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721799
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721800
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721801
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721802
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721803
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721804
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721805
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721806
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721807
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721808
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721809
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721810
# 20-Dec-2021 22:51:10 DEBUG GEOparse - SAMPLE: GSM4721811

# %% [markdown]
# We need to preprocess the metadata: for each sample we want the following columns: idseq_sample_name (name of matching IDSeq sample (used to map to count data)), gender (gender of patient), age (age of patient), sc2_pcr (result of SARS-COV-2 PCR test, this determines whether the patient is in the COVID group or not), sc2_rpm (reads-per-million mapping to SARS-COV-2 metagenomic sequencing data), and viral_status (either SC2 (for SARS-CoV-2), other_virus or no_virus).

# %%
gse.gsms['GSM4721578'].metadata
# Out:
# {'channel_count': ['1'],
#  'characteristics_ch1': ['gender: F',
#   'age: 62',
#   'sars-cov-2 rpm: NEG',
#   'sars-cov-2 pcr: 0.313853190805252',
#   'disease state: no virus'],
#  'contact_address': ['499 Illinois St'],
#  'contact_city': ['San Francisco'],
#  'contact_country': ['USA'],
#  'contact_department': ['Medicine'],
#  'contact_email': ['chaz.langelier@ucsf.edu, chazlangelier@gmail.com'],
#  'contact_institute': ['University of California San Francisco'],
#  'contact_name': ['Charles,,Langelier'],
#  'contact_phone': ['801-201-5049'],
#  'contact_state': ['CA'],
#  'contact_zip/postal_code': ['94158'],
#  'data_processing': ['Alignment against human genome- Kallisto v 0.46.1',
#   'Gene-level counts were generated from the transcript-level abundance estimates using the R package tximport',
#   'Fitering to retain samples with 400,000 gene counts',
#   'Differential expression with R package limma',
#   'Genome_build: HG-38, ENSEMBL v. 99',
#   'Supplementary_files_format_and_content: .csv files with genecounts'],
#  'data_row_count': ['0'],
#  'description': ['RR057e_00202'],
#  'extract_protocol_ch1': ['Zymo DNA/RNA magbead',
#   'NEBnext with Qiagen Fastselect rRNA depletion'],
#  'geo_accession': ['GSM4721578'],
#  'growth_protocol_ch1': ['Clinical naso/pharyngeal swab specimens'],
#  'instrument_model': ['Illumina NovaSeq 6000'],
#  'last_update_date': ['Aug 12 2020'],
#  'library_selection': ['cDNA'],
#  'library_source': ['transcriptomic'],
#  'library_strategy': ['RNA-Seq'],
#  'molecule_ch1': ['total RNA'],
#  'organism_ch1': ['Homo sapiens'],
#  'platform_id': ['GPL24676'],
#  'relation': ['BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN15793150'],
#  'series_id': ['GSE156063'],
#  'source_name_ch1': ['NP/OP swab'],
#  'status': ['Public on Aug 12 2020'],
#  'submission_date': ['Aug 11 2020'],
#  'supplementary_file_1': ['NONE'],
#  'taxid_ch1': ['9606'],
#  'title': ['RR057e_00202_N05_S78'],
#  'treatment_protocol_ch1': ['DNAse'],
#  'type': ['SRA']}

# %%
import pandas as pd

# Columns we want in our metadata DataFrame:
columns = ['idseq_sample_name', 'gender', 'age', 'sc2_pcr', 'sc2_rpm', 'viral_status']

# From the above example of the metadata from a sample, we find that the 'title' key maps to 
# the 'idseq_sample_name' and the 'characteristics_ch1' key maps to a list that has a dictionary-type 
# structure, we want all 5 of these values: 'age', 'gender', 'sars-cov-2 rpm' which actually should be
# 'sc2_pcr', 'sars-cov-2 pcr' which actually should be 'sc2_rpm', and viral_status.
ch_column = 'characteristics_ch1'
characteristics = ['gender', 'age', 'sars-cov-2 rpm', 'sars-cov-2 pcr', 'disease state']

# Create list of titles and characteristic dictionary to later be combined and converted into a Dataframe
titles = []
ch_dict = {}
for ch in characteristics:
    ch_dict.update({ch : []})

# Iterate through the 234 samples and construct the metadata DataFrame
for gsm in gse.gsms.keys():
    titles.append(gse.gsms[gsm].metadata['title'][0])
    for ch in gse.gsms[gsm].metadata[ch_column]:
        x = ch.split(': ')
        ch_dict[x[0]].append("_".join(x[1].split(" "))) # want to remove the space in viral_status

# Create metadata dictionary, copy in titles & ch_dict, and convert it to DataFrame
metadata = {}
metadata['idseq_sample_name'] = titles
for i in range(len(characteristics)):
    metadata[columns[i+1]] = ch_dict[characteristics[i]]
metadata = pd.DataFrame.from_dict(metadata)
metadata.head()
# Out:
#        idseq_sample_name gender age sc2_pcr            sc2_rpm viral_status
# 0   RR057e_00202_N05_S78      F  62     NEG  0.313853190805252     no_virus
# 1  RR057e_00080_H20_S312      M  81     NEG  0.098334479421691     no_virus
# 2  RR057e_00287_L09_S140      F  76     NEG  0.914830871073219     no_virus
# 3  RR057e_00753_G10_S151      F  36     POS   403.657304115618          SC2
# 4  RR057e_00751_C10_S147      F  58     POS   96314.7658717924          SC2

# %% [markdown]
# Save the preprocessed metadata so that it can be used in the DE analysis (see `DE_Analysis.Rmd`).

# %%
# Write metadata to .txt file
output_metadata_file = DATA / "GSE156063_metadata.txt"

metadata.to_csv(output_metadata_file, sep='\t', index=False)
